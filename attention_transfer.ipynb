# %%
# !pip install torchnet
# !pip install utils

# !pip install tqdm
# !pip install nested_dict
# !pip install numpy
# !pip install torch
# !pip install torchnet
# !pip install torchvision
# Out:
# Collecting torchnet
#   Downloading https://files.pythonhosted.org/packages/b7/b2/d7f70a85d3f6b0365517782632f150e3bbc2fb8e998cd69e27deba599aae/torchnet-0.0.4.tar.gz
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchnet) (1.5.0+cu101)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchnet) (1.12.0)
# Collecting visdom
#   Downloading https://files.pythonhosted.org/packages/c9/75/e078f5a2e1df7e0d3044749089fc2823e62d029cc027ed8ae5d71fafcbdc/visdom-0.1.8.9.tar.gz (676kB)
#      |████████████████████████████████| 686kB 5.1MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->torchnet) (1.18.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->torchnet) (0.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from visdom->torchnet) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from visdom->torchnet) (2.23.0)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from visdom->torchnet) (4.5.3)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from visdom->torchnet) (19.0.0)
# Collecting jsonpatch
#   Downloading https://files.pythonhosted.org/packages/82/53/73ca86f2a680c705dcd1708be4887c559dfe9ed250486dd3ccd8821b8ccb/jsonpatch-1.25-py2.py3-none-any.whl
# Collecting torchfile
#   Downloading https://files.pythonhosted.org/packages/91/af/5b305f86f2d218091af657ddb53f984ecbd9518ca9fe8ef4103a007252c9/torchfile-0.1.0.tar.gz
# Collecting websocket-client
#   Downloading https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200kB)
#      |████████████████████████████████| 204kB 41.8MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from visdom->torchnet) (7.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->visdom->torchnet) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->visdom->torchnet) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->visdom->torchnet) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->visdom->torchnet) (2020.4.5.1)
# Collecting jsonpointer>=1.9
#   Downloading https://files.pythonhosted.org/packages/18/b0/a80d29577c08eea401659254dfaed87f1af45272899e1812d7e01b679bc5/jsonpointer-2.0-py2.py3-none-any.whl
# Building wheels for collected packages: torchnet, visdom, torchfile
#   Building wheel for torchnet (setup.py) ... done
#   Created wheel for torchnet: filename=torchnet-0.0.4-cp36-none-any.whl size=29744 sha256=efc9539698d52c4a2bb28dd6aec3289a5dfa7bb5df9fcc4382d4c71ea5434f49
#   Stored in directory: /root/.cache/pip/wheels/e1/03/fb/1c212c2f20905cdf97fe39022946cf16b8e66ed754a6663400
#   Building wheel for visdom (setup.py) ... done
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp36-none-any.whl size=655250 sha256=abe0a714665aa26872f310eba975bf013a1a8e2bb623bc6d53c4485e169b7013
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
#   Building wheel for torchfile (setup.py) ... done
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp36-none-any.whl size=5712 sha256=7a42885a056d130bbec689dfed21224678408ecf4958601be89bdfec83fc4335
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built torchnet visdom torchfile
# Installing collected packages: jsonpointer, jsonpatch, torchfile, websocket-client, visdom, torchnet
# Successfully installed jsonpatch-1.25 jsonpointer-2.0 torchfile-0.1.0 torchnet-0.0.4 visdom-0.1.8.9 websocket-client-0.57.0
# Collecting utils
#   Downloading https://files.pythonhosted.org/packages/55/e6/c2d2b2703e7debc8b501caae0e6f7ead148fd0faa3c8131292a599930029/utils-1.0.1-py2.py3-none-any.whl
# Installing collected packages: utils
# Successfully installed utils-1.0.1
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.38.0)
# Collecting nested_dict
#   Downloading https://files.pythonhosted.org/packages/42/d0/3b27fa65b16a2e44d793af59929fcdb3bb84b4664462ff2830105dfd9b7d/nested_dict-1.61.tar.gz
# Building wheels for collected packages: nested-dict
#   Building wheel for nested-dict (setup.py) ... done
#   Created wheel for nested-dict: filename=nested_dict-1.61-cp36-none-any.whl size=6426 sha256=67f50f7f88ace462f8d0f91d6dce16c2eb7c64b92a91e35ceb5643a89677480a
#   Stored in directory: /root/.cache/pip/wheels/44/fc/9e/66585e4a7585503d1270ab23150805d29bfa65f4c26c5fea2d
# Successfully built nested-dict
# Installing collected packages: nested-dict
# Successfully installed nested-dict-1.61
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (1.18.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.5.0+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch) (1.18.3)
# Requirement already satisfied: torchnet in /usr/local/lib/python3.6/dist-packages (0.0.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchnet) (1.5.0+cu101)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchnet) (1.12.0)
# Requirement already satisfied: visdom in /usr/local/lib/python3.6/dist-packages (from torchnet) (0.1.8.9)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->torchnet) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->torchnet) (1.18.3)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.6/dist-packages (from visdom->torchnet) (0.57.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from visdom->torchnet) (1.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from visdom->torchnet) (7.0.0)
# Requirement already satisfied: torchfile in /usr/local/lib/python3.6/dist-packages (from visdom->torchnet) (0.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from visdom->torchnet) (2.23.0)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from visdom->torchnet) (4.5.3)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from visdom->torchnet) (19.0.0)
# Requirement already satisfied: jsonpatch in /usr/local/lib/python3.6/dist-packages (from visdom->torchnet) (1.25)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->visdom->torchnet) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->visdom->torchnet) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->visdom->torchnet) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->visdom->torchnet) (1.24.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.6/dist-packages (from jsonpatch->visdom->torchnet) (2.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.6.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.18.3)
# Requirement already satisfied: torch==1.5.0 in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.5.0+cu101)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (7.0.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.5.0->torchvision) (0.16.0)

# %%
from nested_dict import nested_dict
from functools import partial
import torch
from torch.nn.init import kaiming_normal_
from torch.nn.parallel._functions import Broadcast
from torch.nn.parallel import scatter, parallel_apply, gather
import torch.nn.functional as F


def distillation(y, teacher_scores, labels, T, alpha):
    p = F.log_softmax(y/T, dim=1)
    q = F.softmax(teacher_scores/T, dim=1)
    l_kl = F.kl_div(p, q, size_average=False) * (T**2) / y.shape[0]
    l_ce = F.cross_entropy(y, labels)
    return l_kl * alpha + l_ce * (1. - alpha)


def at(x):
    return F.normalize(x.pow(2).mean(1).view(x.size(0), -1))


def at_loss(x, y):
    print("INSIDE AT_LOSS")
    print(x.shape)
    print(y.shape)
    print(at(x).shape)
    print(at(y).shape)
    return (at(x) - at(y)).pow(4).mean()


def cast(params, dtype='float'):
    if isinstance(params, dict):
        return {k: cast(v, dtype) for k,v in params.items()}
    else:
        return getattr(params.cuda() if torch.cuda.is_available() else params, dtype)()


def conv_params(ni, no, k=1):
    return kaiming_normal_(torch.Tensor(no, ni, k, k))


def linear_params(ni, no):
    return {'weight': kaiming_normal_(torch.Tensor(no, ni)), 'bias': torch.zeros(no)}


def bnparams(n):
    return {'weight': torch.rand(n),
            'bias': torch.zeros(n),
            'running_mean': torch.zeros(n),
            'running_var': torch.ones(n)}


def data_parallel(f, input, params, mode, device_ids, output_device=None):
    device_ids = list(device_ids)
    if output_device is None:
        output_device = device_ids[0]

    if len(device_ids) == 1:
        return f(input, params, mode)

    params_all = Broadcast.apply(device_ids, *params.values())
    params_replicas = [{k: params_all[i + j*len(params)] for i, k in enumerate(params.keys())}
                       for j in range(len(device_ids))]

    replicas = [partial(f, params=p, mode=mode)
                for p in params_replicas]
    inputs = scatter([input], device_ids)
    outputs = parallel_apply(replicas, inputs)
    return gather(outputs, output_device)


def flatten(params):
    return {'.'.join(k): v for k, v in nested_dict(params).items_flat() if v is not None}


def batch_norm(x, params, base, mode):
    return F.batch_norm(x, weight=params[base + '.weight'],
                        bias=params[base + '.bias'],
                        running_mean=params[base + '.running_mean'],
                        running_var=params[base + '.running_var'],
                        training=mode)


def print_tensor_dict(params):
    kmax = max(len(key) for key in params.keys())
    for i, (key, v) in enumerate(params.items()):
        print(str(i).ljust(5), key.ljust(kmax + 3), str(tuple(v.shape)).ljust(23), torch.typename(v), v.requires_grad)


def set_requires_grad_except_bn_(params):
    for k, v in params.items():
        if not k.endswith('running_mean') and not k.endswith('running_var'):
            v.requires_grad = True

# %%
import argparse
import os
import json
import numpy as np
from tqdm import tqdm
import torch
from torch.optim import SGD
import torchvision.transforms as T
from torchvision import datasets
import torch.nn.functional as F
import torchnet as tnt
from torchnet.engine import Engine
from torch.utils.data import DataLoader
import torch.backends.cudnn as cudnn
import utils
from easydict import EasyDict

cudnn.benchmark = True

# %%
def model_parameters(args):
  epoch_step = json.loads(args.epoch_step)
  num_classes = args.classes
  
  def create_dataset(args, train):

    transform = T.Compose([
        T.ToTensor(),
        T.Normalize(np.array([125.3, 123.0, 113.9]) / 255.0,
                    np.array([63.0, 62.1, 66.7]) / 255.0),
    ])
    if args.channel==0:
      transform = T.Compose([
        T.ToTensor(),
        T.Normalize((0.5,), (0.5,))
      ])
    if train:
        transform = T.Compose([
            T.Pad(4, padding_mode='reflect'),
            T.RandomHorizontalFlip(),
            T.RandomCrop(32),
            transform
        ])
    return getattr(datasets, args.dataset)(args.dataroot, train=train, download=True, transform=transform)

  def create_iterator(mode):
          return DataLoader(create_dataset(args, mode), args.batch_size, shuffle=mode,
                            num_workers=args.nthread, pin_memory=torch.cuda.is_available())

  train_loader = create_iterator(True)
  test_loader = create_iterator(False)
  
  c=0
  if args.channel==0:
    c=1
  else:
    c=3
  
  def resnet(depth, width, num_classes):
      assert (depth - 4) % 6 == 0, 'depth should be 6n+4'
      n = (depth - 4) // 6
      widths = [int(v * width) for v in (16, 32, 64)]

      def gen_block_params(ni, no):
          return {
              'conv0': conv_params(ni, no, 3),
              'conv1': conv_params(no, no, 3),
              'bn0': bnparams(ni),
              'bn1': bnparams(no),
              'convdim': conv_params(ni, no, 1) if ni != no else None,
          }

      def gen_group_params(ni, no, count):
          return {'block%d' % i: gen_block_params(ni if i == 0 else no, no)
                  for i in range(count)}
      flat_params = cast(flatten({
          'conv0': conv_params(c, 16, 3),
          'group0': gen_group_params(16, widths[0], n),
          'group1': gen_group_params(widths[0], widths[1], n),
          'group2': gen_group_params(widths[1], widths[2], n),
          'bn': bnparams(widths[2]),
          'fc': linear_params(widths[2], num_classes),
      }))

      set_requires_grad_except_bn_(flat_params)

      def block(x, params, base, mode, stride):
          #print("INSIDE BLOCK")
          #print(x.shape)
          o1 = F.relu(batch_norm(x, params, base + '.bn0', mode), inplace=True)
          #print(o1.shape)
          y = F.conv2d(o1, params[base + '.conv0'], stride=stride, padding=1)
          #print(y.shape)
          o2 = F.relu(batch_norm(y, params, base + '.bn1', mode), inplace=True)
          #print(o2.shape)
          z = F.conv2d(o2, params[base + '.conv1'], stride=1, padding=1)
          #print(z.shape)
          if base + '.convdim' in params:
              #print("HERE in block")
              #print(z.shape)
              #print(F.conv2d(o1, params[base + '.convdim'], stride=stride).shape)
              return z + F.conv2d(o1, params[base + '.convdim'], stride=stride)
          else:
              return z + x

      def group(o, params, base, mode, stride):
          for i in range(n):
              o = block(o, params, f'{base}.block{i}', mode, stride if i == 0 else 1)
          return o

      def f(input, params, mode, base=''):
          #print("HERE F")
          #print(input.shape)
          x = F.conv2d(input, params[f'{base}conv0'], padding=1)
          #print("x")
          #print(x.shape)
          #print(x.shape)
          g0 = group(x, params, f'{base}group0', mode, 1)
          #print(g0.shape)
          g1 = group(g0, params, f'{base}group1', mode, 2)
          #print(g1.shape)
          g2 = group(g1, params, f'{base}group2', mode, 2)
          #print(g2.shape)
          o = F.relu(batch_norm(g2, params, f'{base}bn', mode))
          #print(o.shape)
          o = F.avg_pool2d(o, 8, 1, 0)
          #print(o.shape)
          o = o.view(o.size(0), -1)
          #print(o.shape)
          o = F.linear(o, params[f'{base}fc.weight'], params[f'{base}fc.bias'])
          #print(o.shape)
          return o, (g0, g1, g2)

      return f, flat_params




  f_s, params_s = resnet(args.depth, args.width, num_classes)
  if args.teacher_id:
          with open(os.path.join('logs', args.teacher_id, 'log.txt'), 'r') as ff:
              line = ff.readline()
              r = line.find('json_stats')
              info = json.loads(line[r + 12:])
          f_t = resnet(info['depth'], info['width'], num_classes)[0]
          model_data = torch.load(os.path.join('logs', args.teacher_id, 'model.pt7'))
          params_t = model_data['params']

          # merge teacher and student params
          params = {'student.' + k: v for k, v in params_s.items()}
          for k, v in params_t.items():
              params['teacher.' + k] = v.detach().requires_grad_(False)

          def f(inputs, params, mode):
              y_s, g_s = f_s(inputs, params, mode, 'student.')
              with torch.no_grad():
                  y_t, g_t = f_t(inputs, params, False, 'teacher.')
              return y_s, y_t, [at_loss(x, y) for x, y in zip(g_s, g_t)]
  else:
    f, params = f_s, params_s

  def create_optimizer(args, lr):
        print('creating optimizer with lr = ', lr)
        return SGD((v for v in params.values() if v.requires_grad), lr,
                   momentum=0.9, weight_decay=args.weight_decay)
  
  optimizer = create_optimizer(args, args.lr)
  
  
  epoch = 0
  
  if args.resume != '':
    state_dict = torch.load(args.resume)
    epoch = state_dict['epoch']
    params_tensors = state_dict['params']
    for k, v in params.items():
        v.data.copy_(params_tensors[k])
    optimizer.load_state_dict(state_dict['optimizer'])
    print("HERE")

  print('\nParameters:')
  print_tensor_dict(params)
  n_parameters = sum(p.numel() for p in list(params_s.values()))
  print('\nTotal number of parameters:', n_parameters)


  meter_loss = tnt.meter.AverageValueMeter()
  classacc = tnt.meter.ClassErrorMeter(accuracy=True)
  timer_train = tnt.meter.TimeMeter('s')
  timer_test = tnt.meter.TimeMeter('s')
  meters_at = [tnt.meter.AverageValueMeter() for i in range(3)]

  if not os.path.exists(args.save):
    os.mkdir(args.save)

  def h(sample):
        inputs = cast(sample[0], args.dtype).detach()
        targets = cast(sample[1], 'long')
        #print("INSIDE H")
        #print(inputs.shape)
        if inputs.shape[2]!=32:
          inputs = torch.nn.functional.pad(inputs, (3, 1, 3, 1))
        #print(inputs.shape)
        #print(targets.shape)
        if args.teacher_id != '':
            y_s, y_t, loss_groups = data_parallel(f, inputs, params, sample[2], range(1))
            print("LOSS _ GROUPS BEFORE")
            print(loss_groups)
            print(len(loss_groups))
            loss_groups = [v.sum() for v in loss_groups]
            print("LOSS _ GROUPS AFTER")
            print(loss_groups)
            [m.add(v.item()) for m, v in zip(meters_at, loss_groups)]
            return distillation(y_s, y_t, targets, args.temperature, args.alpha) \
                   + args.beta * sum(loss_groups), y_s
        else:
            y = data_parallel(f, inputs, params, sample[2], range(1))[0]
            return F.cross_entropy(y, targets), y

  def log(t, state):
      torch.save(dict(params={k: v.data for k, v in params.items()},
                      optimizer=state['optimizer'].state_dict(),
                      epoch=t['epoch']),
                  os.path.join(args.save, 'model.pt7'))
      z = vars(args).copy(); z.update(t)
      logname = os.path.join(args.save, 'log.txt')
      with open(logname, 'a') as f:
          f.write('json_stats: ' + json.dumps(z) + '\n')
      print(z)

  def on_sample(state):
      state['sample'].append(state['train'])

  def on_forward(state):
      classacc.add(state['output'].data, state['sample'][1])
      meter_loss.add(state['loss'].item())  

  def on_start(state):
        state['epoch'] = epoch

  def on_start_epoch(state):
      classacc.reset()
      meter_loss.reset()
      timer_train.reset()
      [meter.reset() for meter in meters_at]
      state['iterator'] = tqdm(train_loader)

      epoch = state['epoch'] + 1
      if epoch in epoch_step:
          lr = state['optimizer'].param_groups[0]['lr']
          state['optimizer'] = create_optimizer(args, lr * args.lr_decay_ratio)

  def on_end_epoch(state):
      train_loss = meter_loss.mean
      train_acc = classacc.value()
      train_time = timer_train.value()
      meter_loss.reset()
      classacc.reset()
      timer_test.reset()

      #print("IT CAME HERE")
      engine.test(h, test_loader)
      #print("FINISHED TESTIG")
      test_acc = classacc.value()[0]
      print(log({
          "train_loss": train_loss,
          "train_acc": train_acc[0],
          "test_loss": meter_loss.mean,
          "test_acc": test_acc,
          "epoch": state['epoch'],
          "num_classes": num_classes,
          "n_parameters": n_parameters,
          "train_time": train_time,
          "test_time": timer_test.value(),
          "at_losses": [m.value() for m in meters_at],
          }, state))
      print('==> id: %s (%d/%d), test_acc: \33[91m%.2f\033[0m' % \
                      (args.save, state['epoch'], args.epochs, test_acc))


  engine = Engine()
  engine.hooks['on_sample'] = on_sample
  engine.hooks['on_forward'] = on_forward
  engine.hooks['on_start_epoch'] = on_start_epoch
  engine.hooks['on_end_epoch'] = on_end_epoch
  engine.hooks['on_start'] = on_start
  engine.train(h, train_loader, args.epochs, optimizer)

  return engine

# %%
teacher_args = EasyDict({
    "channel": 0,
    "classes": 10,
    "depth": 16,
    "width": 2,
    "dataset" : 'FashionMNIST',
    "dataroot" : '.',
    "dtype" : 'float',
    "nthread" : 0,
    "teacher_id" : '',
    "batch_size" : 128,
    "lr" : 0.1,
    "epochs" : 1,
    "weight_decay" : 0.0005,
    "epoch_step" : '[60, 120, 160]',
    "lr_decay_ratio" : 0.2,
    "resume" : '',
    "randomcrop_pad" : 4,
    "temperature" : 4,
    "alpha" : 0,
    "beta" : 0,
    "gpu_id" : '0',
    "save" : '/content/logs/resnet_52_2_teacher'
})

print('parsed options:', teacher_args)
teacher = model_parameters(teacher_args)
# Out:
# parsed options: {'channel': 0, 'classes': 10, 'depth': 16, 'width': 2, 'dataset': 'FashionMNIST', 'dataroot': '.', 'dtype': 'float', 'nthread': 0, 'teacher_id': '', 'batch_size': 128, 'lr': 0.1, 'epochs': 1, 'weight_decay': 0.0005, 'epoch_step': '[60, 120, 160]', 'lr_decay_ratio': 0.2, 'resume': '', 'randomcrop_pad': 4, 'temperature': 4, 'alpha': 0, 'beta': 0, 'gpu_id': '0', 'save': '/content/logs/resnet_52_2_teacher'}
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./FashionMNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./FashionMNIST/raw/train-images-idx3-ubyte.gz to ./FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./FashionMNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./FashionMNIST/raw
# Processing...
# Done!
# /pytorch/torch/csrc/utils/tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.
#   0%|          | 0/469 [00:00<?, ?it/s]
# creating optimizer with lr =  0.1
#
# Parameters:
# 0     conv0                             (16, 1, 3, 3)           torch.cuda.FloatTensor True
# 1     group0.block0.conv0               (32, 16, 3, 3)          torch.cuda.FloatTensor True
# 2     group0.block0.conv1               (32, 32, 3, 3)          torch.cuda.FloatTensor True
# 3     group0.block0.bn0.weight          (16,)                   torch.cuda.FloatTensor True
# 4     group0.block0.bn0.bias            (16,)                   torch.cuda.FloatTensor True
# 5     group0.block0.bn0.running_mean    (16,)                   torch.cuda.FloatTensor False
# 6     group0.block0.bn0.running_var     (16,)                   torch.cuda.FloatTensor False
# 7     group0.block0.bn1.weight          (32,)                   torch.cuda.FloatTensor True
# 8     group0.block0.bn1.bias            (32,)                   torch.cuda.FloatTensor True
# 9     group0.block0.bn1.running_mean    (32,)                   torch.cuda.FloatTensor False
# 10    group0.block0.bn1.running_var     (32,)                   torch.cuda.FloatTensor False
# 11    group0.block0.convdim             (32, 16, 1, 1)          torch.cuda.FloatTensor True
# 12    group0.block1.conv0               (32, 32, 3, 3)          torch.cuda.FloatTensor True
# 13    group0.block1.conv1               (32, 32, 3, 3)          torch.cuda.FloatTensor True
# 14    group0.block1.bn0.weight          (32,)                   torch.cuda.FloatTensor True
# 15    group0.block1.bn0.bias            (32,)                   torch.cuda.FloatTensor True
# 16    group0.block1.bn0.running_mean    (32,)                   torch.cuda.FloatTensor False
# 17    group0.block1.bn0.running_var     (32,)                   torch.cuda.FloatTensor False
# 18    group0.block1.bn1.weight          (32,)                   torch.cuda.FloatTensor True
# 19    group0.block1.bn1.bias            (32,)                   torch.cuda.FloatTensor True
# 20    group0.block1.bn1.running_mean    (32,)                   torch.cuda.FloatTensor False
# 21    group0.block1.bn1.running_var     (32,)                   torch.cuda.FloatTensor False
# 22    group1.block0.conv0               (64, 32, 3, 3)          torch.cuda.FloatTensor True
# 23    group1.block0.conv1               (64, 64, 3, 3)          torch.cuda.FloatTensor True
# 24    group1.block0.bn0.weight          (32,)                   torch.cuda.FloatTensor True
# 25    group1.block0.bn0.bias            (32,)                   torch.cuda.FloatTensor True
# 26    group1.block0.bn0.running_mean    (32,)                   torch.cuda.FloatTensor False
# 27    group1.block0.bn0.running_var     (32,)                   torch.cuda.FloatTensor False
# 28    group1.block0.bn1.weight          (64,)                   torch.cuda.FloatTensor True
# 29    group1.block0.bn1.bias            (64,)                   torch.cuda.FloatTensor True
# 30    group1.block0.bn1.running_mean    (64,)                   torch.cuda.FloatTensor False
# 31    group1.block0.bn1.running_var     (64,)                   torch.cuda.FloatTensor False
# 32    group1.block0.convdim             (64, 32, 1, 1)          torch.cuda.FloatTensor True
# 33    group1.block1.conv0               (64, 64, 3, 3)          torch.cuda.FloatTensor True
# 34    group1.block1.conv1               (64, 64, 3, 3)          torch.cuda.FloatTensor True
# 35    group1.block1.bn0.weight          (64,)                   torch.cuda.FloatTensor True
# 36    group1.block1.bn0.bias            (64,)                   torch.cuda.FloatTensor True
# 37    group1.block1.bn0.running_mean    (64,)                   torch.cuda.FloatTensor False
# 38    group1.block1.bn0.running_var     (64,)                   torch.cuda.FloatTensor False
# 39    group1.block1.bn1.weight          (64,)                   torch.cuda.FloatTensor True
# 40    group1.block1.bn1.bias            (64,)                   torch.cuda.FloatTensor True
# 41    group1.block1.bn1.running_mean    (64,)                   torch.cuda.FloatTensor False
# 42    group1.block1.bn1.running_var     (64,)                   torch.cuda.FloatTensor False
# 43    group2.block0.conv0               (128, 64, 3, 3)         torch.cuda.FloatTensor True
# 44    group2.block0.conv1               (128, 128, 3, 3)        torch.cuda.FloatTensor True
# 45    group2.block0.bn0.weight          (64,)                   torch.cuda.FloatTensor True
# 46    group2.block0.bn0.bias            (64,)                   torch.cuda.FloatTensor True
# 47    group2.block0.bn0.running_mean    (64,)                   torch.cuda.FloatTensor False
# 48    group2.block0.bn0.running_var     (64,)                   torch.cuda.FloatTensor False
# 49    group2.block0.bn1.weight          (128,)                  torch.cuda.FloatTensor True
# 50    group2.block0.bn1.bias            (128,)                  torch.cuda.FloatTensor True
# 51    group2.block0.bn1.running_mean    (128,)                  torch.cuda.FloatTensor False
# 52    group2.block0.bn1.running_var     (128,)                  torch.cuda.FloatTensor False
# 53    group2.block0.convdim             (128, 64, 1, 1)         torch.cuda.FloatTensor True
# 54    group2.block1.conv0               (128, 128, 3, 3)        torch.cuda.FloatTensor True
# 55    group2.block1.conv1               (128, 128, 3, 3)        torch.cuda.FloatTensor True
# 56    group2.block1.bn0.weight          (128,)                  torch.cuda.FloatTensor True
# 57    group2.block1.bn0.bias            (128,)                  torch.cuda.FloatTensor True
# 58    group2.block1.bn0.running_mean    (128,)                  torch.cuda.FloatTensor False
# 59    group2.block1.bn0.running_var     (128,)                  torch.cuda.FloatTensor False
# 60    group2.block1.bn1.weight          (128,)                  torch.cuda.FloatTensor True
# 61    group2.block1.bn1.bias            (128,)                  torch.cuda.FloatTensor True
# 62    group2.block1.bn1.running_mean    (128,)                  torch.cuda.FloatTensor False
# 63    group2.block1.bn1.running_var     (128,)                  torch.cuda.FloatTensor False
# 64    bn.weight                         (128,)                  torch.cuda.FloatTensor True
# 65    bn.bias                           (128,)                  torch.cuda.FloatTensor True
# 66    bn.running_mean                   (128,)                  torch.cuda.FloatTensor False
# 67    bn.running_var                    (128,)                  torch.cuda.FloatTensor False
# 68    fc.weight                         (10, 128)               torch.cuda.FloatTensor True
# 69    fc.bias                           (10,)                   torch.cuda.FloatTensor True
#
# Total number of parameters: 693210
# 100%|██████████| 469/469 [00:41<00:00, 11.43it/s]
# {'channel': 0, 'classes': 10, 'depth': 16, 'width': 2, 'dataset': 'FashionMNIST', 'dataroot': '.', 'dtype': 'float', 'nthread': 0, 'teacher_id': '', 'batch_size': 128, 'lr': 0.1, 'epochs': 1, 'weight_decay': 0.0005, 'epoch_step': '[60, 120, 160]', 'lr_decay_ratio': 0.2, 'resume': '', 'randomcrop_pad': 4, 'temperature': 4, 'alpha': 0, 'beta': 0, 'gpu_id': '0', 'save': '/content/logs/resnet_52_2_teacher', 'train_loss': 0.5896742646373924, 'train_acc': 78.38000000000001, 'test_loss': 2.275277966185461, 'test_acc': 44.46, 'epoch': 1, 'num_classes': 10, 'n_parameters': 693210, 'train_time': 41.05589175224304, 'test_time': 2.5025694370269775, 'at_losses': [(nan, nan), (nan, nan), (nan, nan)]}
# None
# ==> id: /content/logs/resnet_52_2_teacher (1/1), test_acc: 44.46

# %%
student_trained_args = EasyDict({
    "channel": 0,
    "classes": 10,
    "depth": 10,
    "width": 1,
    "dataset" : 'FashionMNIST',
    "dataroot" : '.',
    "dtype" : 'float',
    "nthread" : 4,
    "teacher_id" : 'resnet_52_2_teacher',
    "batch_size" : 128,
    "lr" : 0.1,
    "epochs" : 3,
    "weight_decay" : 0.0005,
    "epoch_step" : '[60, 120, 160]',
    "lr_decay_ratio" : 0.2,
    "resume" : '',
    "randomcrop_pad" : 4,
    "temperature" : 4,
    "alpha" : 0,
    "beta" : 1000,
    "gpu_id" : '0',
    "save" : '/content/logs/at_52_2_16_1'
})

print('parsed options:', student_trained_args)
student_trained = model_parameters(student_trained_args)
# Out:
#   0%|          | 0/469 [00:00<?, ?it/s]
# parsed options: {'channel': 0, 'classes': 10, 'depth': 10, 'width': 1, 'dataset': 'FashionMNIST', 'dataroot': '.', 'dtype': 'float', 'nthread': 4, 'teacher_id': 'resnet_52_2_teacher', 'batch_size': 128, 'lr': 0.1, 'epochs': 3, 'weight_decay': 0.0005, 'epoch_step': '[60, 120, 160]', 'lr_decay_ratio': 0.2, 'resume': '', 'randomcrop_pad': 4, 'temperature': 4, 'alpha': 0, 'beta': 1000, 'gpu_id': '0', 'save': '/content/logs/at_52_2_16_1'}
# creating optimizer with lr =  0.1
#
# Parameters:
# 0     student.conv0                             (16, 1, 3, 3)           torch.cuda.FloatTensor True
# 1     student.group0.block0.conv0               (16, 16, 3, 3)          torch.cuda.FloatTensor True
# 2     student.group0.block0.conv1               (16, 16, 3, 3)          torch.cuda.FloatTensor True
# 3     student.group0.block0.bn0.weight          (16,)                   torch.cuda.FloatTensor True
# 4     student.group0.block0.bn0.bias            (16,)                   torch.cuda.FloatTensor True
# 5     student.group0.block0.bn0.running_mean    (16,)                   torch.cuda.FloatTensor False
# 6     student.group0.block0.bn0.running_var     (16,)                   torch.cuda.FloatTensor False
# 7     student.group0.block0.bn1.weight          (16,)                   torch.cuda.FloatTensor True
# 8     student.group0.block0.bn1.bias            (16,)                   torch.cuda.FloatTensor True
# 9     student.group0.block0.bn1.running_mean    (16,)                   torch.cuda.FloatTensor False
# 10    student.group0.block0.bn1.running_var     (16,)                   torch.cuda.FloatTensor False
# 11    student.group1.block0.conv0               (32, 16, 3, 3)          torch.cuda.FloatTensor True
# 12    student.group1.block0.conv1               (32, 32, 3, 3)          torch.cuda.FloatTensor True
# 13    student.group1.block0.bn0.weight          (16,)                   torch.cuda.FloatTensor True
# 14    student.group1.block0.bn0.bias            (16,)                   torch.cuda.FloatTensor True
# 15    student.group1.block0.bn0.running_mean    (16,)                   torch.cuda.FloatTensor False
# 16    student.group1.block0.bn0.running_var     (16,)                   torch.cuda.FloatTensor False
# 17    student.group1.block0.bn1.weight          (32,)                   torch.cuda.FloatTensor True
# 18    student.group1.block0.bn1.bias            (32,)                   torch.cuda.FloatTensor True
# 19    student.group1.block0.bn1.running_mean    (32,)                   torch.cuda.FloatTensor False
# 20    student.group1.block0.bn1.running_var     (32,)                   torch.cuda.FloatTensor False
# 21    student.group1.block0.convdim             (32, 16, 1, 1)          torch.cuda.FloatTensor True
# 22    student.group2.block0.conv0               (64, 32, 3, 3)          torch.cuda.FloatTensor True
# 23    student.group2.block0.conv1               (64, 64, 3, 3)          torch.cuda.FloatTensor True
# 24    student.group2.block0.bn0.weight          (32,)                   torch.cuda.FloatTensor True
# 25    student.group2.block0.bn0.bias            (32,)                   torch.cuda.FloatTensor True
# 26    student.group2.block0.bn0.running_mean    (32,)                   torch.cuda.FloatTensor False
# 27    student.group2.block0.bn0.running_var     (32,)                   torch.cuda.FloatTensor False
# 28    student.group2.block0.bn1.weight          (64,)                   torch.cuda.FloatTensor True
# 29    student.group2.block0.bn1.bias            (64,)                   torch.cuda.FloatTensor True
# 30    student.group2.block0.bn1.running_mean    (64,)                   torch.cuda.FloatTensor False
# 31    student.group2.block0.bn1.running_var     (64,)                   torch.cuda.FloatTensor False
# 32    student.group2.block0.convdim             (64, 32, 1, 1)          torch.cuda.FloatTensor True
# 33    student.bn.weight                         (64,)                   torch.cuda.FloatTensor True
# 34    student.bn.bias                           (64,)                   torch.cuda.FloatTensor True
# 35    student.bn.running_mean                   (64,)                   torch.cuda.FloatTensor False
# 36    student.bn.running_var                    (64,)                   torch.cuda.FloatTensor False
# 37    student.fc.weight                         (10, 64)                torch.cuda.FloatTensor True
# 38    student.fc.bias                           (10,)                   torch.cuda.FloatTensor True
# 39    teacher.conv0                             (16, 1, 3, 3)           torch.cuda.FloatTensor False
# 40    teacher.group0.block0.conv0               (32, 16, 3, 3)          torch.cuda.FloatTensor False
# 41    teacher.group0.block0.conv1               (32, 32, 3, 3)          torch.cuda.FloatTensor False
# 42    teacher.group0.block0.bn0.weight          (16,)                   torch.cuda.FloatTensor False
# 43    teacher.group0.block0.bn0.bias            (16,)                   torch.cuda.FloatTensor False
# 44    teacher.group0.block0.bn0.running_mean    (16,)                   torch.cuda.FloatTensor False
# 45    teacher.group0.block0.bn0.running_var     (16,)                   torch.cuda.FloatTensor False
# 46    teacher.group0.block0.bn1.weight          (32,)                   torch.cuda.FloatTensor False
# 47    teacher.group0.block0.bn1.bias            (32,)                   torch.cuda.FloatTensor False
# 48    teacher.group0.block0.bn1.running_mean    (32,)                   torch.cuda.FloatTensor False
# 49    teacher.group0.block0.bn1.running_var     (32,)                   torch.cuda.FloatTensor False
# 50    teacher.group0.block0.convdim             (32, 16, 1, 1)          torch.cuda.FloatTensor False
# 51    teacher.group0.block1.conv0               (32, 32, 3, 3)          torch.cuda.FloatTensor False
# 52    teacher.group0.block1.conv1               (32, 32, 3, 3)          torch.cuda.FloatTensor False
# 53    teacher.group0.block1.bn0.weight          (32,)                   torch.cuda.FloatTensor False
# 54    teacher.group0.block1.bn0.bias            (32,)                   torch.cuda.FloatTensor False
# 55    teacher.group0.block1.bn0.running_mean    (32,)                   torch.cuda.FloatTensor False
# 56    teacher.group0.block1.bn0.running_var     (32,)                   torch.cuda.FloatTensor False
# 57    teacher.group0.block1.bn1.weight          (32,)                   torch.cuda.FloatTensor False
# 58    teacher.group0.block1.bn1.bias            (32,)                   torch.cuda.FloatTensor False
# 59    teacher.group0.block1.bn1.running_mean    (32,)                   torch.cuda.FloatTensor False
# 60    teacher.group0.block1.bn1.running_var     (32,)                   torch.cuda.FloatTensor False
# 61    teacher.group1.block0.conv0               (64, 32, 3, 3)          torch.cuda.FloatTensor False
# 62    teacher.group1.block0.conv1               (64, 64, 3, 3)          torch.cuda.FloatTensor False
# 63    teacher.group1.block0.bn0.weight          (32,)                   torch.cuda.FloatTensor False
# 64    teacher.group1.block0.bn0.bias            (32,)                   torch.cuda.FloatTensor False
# 65    teacher.group1.block0.bn0.running_mean    (32,)                   torch.cuda.FloatTensor False
# 66    teacher.group1.block0.bn0.running_var     (32,)                   torch.cuda.FloatTensor False
# 67    teacher.group1.block0.bn1.weight          (64,)                   torch.cuda.FloatTensor False
# 68    teacher.group1.block0.bn1.bias            (64,)                   torch.cuda.FloatTensor False
# 69    teacher.group1.block0.bn1.running_mean    (64,)                   torch.cuda.FloatTensor False
# 70    teacher.group1.block0.bn1.running_var     (64,)                   torch.cuda.FloatTensor False
# 71    teacher.group1.block0.convdim             (64, 32, 1, 1)          torch.cuda.FloatTensor False
# 72    teacher.group1.block1.conv0               (64, 64, 3, 3)          torch.cuda.FloatTensor False
# 73    teacher.group1.block1.conv1               (64, 64, 3, 3)          torch.cuda.FloatTensor False
# 74    teacher.group1.block1.bn0.weight          (64,)                   torch.cuda.FloatTensor False
# 75    teacher.group1.block1.bn0.bias            (64,)                   torch.cuda.FloatTensor False
# 76    teacher.group1.block1.bn0.running_mean    (64,)                   torch.cuda.FloatTensor False
# 77    teacher.group1.block1.bn0.running_var     (64,)                   torch.cuda.FloatTensor False
# 78    teacher.group1.block1.bn1.weight          (64,)                   torch.cuda.FloatTensor False
# 79    teacher.group1.block1.bn1.bias            (64,)                   torch.cuda.FloatTensor False
# 80    teacher.group1.block1.bn1.running_mean    (64,)                   torch.cuda.FloatTensor False
# 81    teacher.group1.block1.bn1.running_var     (64,)                   torch.cuda.FloatTensor False
# 82    teacher.group2.block0.conv0               (128, 64, 3, 3)         torch.cuda.FloatTensor False
# 83    teacher.group2.block0.conv1               (128, 128, 3, 3)        torch.cuda.FloatTensor False
# 84    teacher.group2.block0.bn0.weight          (64,)                   torch.cuda.FloatTensor False
# 85    teacher.group2.block0.bn0.bias            (64,)                   torch.cuda.FloatTensor False
# 86    teacher.group2.block0.bn0.running_mean    (64,)                   torch.cuda.FloatTensor False
# 87    teacher.group2.block0.bn0.running_var     (64,)                   torch.cuda.FloatTensor False
# 88    teacher.group2.block0.bn1.weight          (128,)                  torch.cuda.FloatTensor False
# 89    teacher.group2.block0.bn1.bias            (128,)                  torch.cuda.FloatTensor False
# 90    teacher.group2.block0.bn1.running_mean    (128,)                  torch.cuda.FloatTensor False
# 91    teacher.group2.block0.bn1.running_var     (128,)                  torch.cuda.FloatTensor False
# 92    teacher.group2.block0.convdim             (128, 64, 1, 1)         torch.cuda.FloatTensor False
# 93    teacher.group2.block1.conv0               (128, 128, 3, 3)        torch.cuda.FloatTensor False
# 94    teacher.group2.block1.conv1               (128, 128, 3, 3)        torch.cuda.FloatTensor False
# 95    teacher.group2.block1.bn0.weight          (128,)                  torch.cuda.FloatTensor False
# 96    teacher.group2.block1.bn0.bias            (128,)                  torch.cuda.FloatTensor False
# 97    teacher.group2.block1.bn0.running_mean    (128,)                  torch.cuda.FloatTensor False
# 98    teacher.group2.block1.bn0.running_var     (128,)                  torch.cuda.FloatTensor False
# 99    teacher.group2.block1.bn1.weight          (128,)                  torch.cuda.FloatTensor False
# 100   teacher.group2.block1.bn1.bias            (128,)                  torch.cuda.FloatTensor False
# 101   teacher.group2.block1.bn1.running_mean    (128,)                  torch.cuda.FloatTensor False
# 102   teacher.group2.block1.bn1.running_var     (128,)                  torch.cuda.FloatTensor False
# 103   teacher.bn.weight                         (128,)                  torch.cuda.FloatTensor False
# 104   teacher.bn.bias                           (128,)                  torch.cuda.FloatTensor False
# 105   teacher.bn.running_mean                   (128,)                  torch.cuda.FloatTensor False
# 106   teacher.bn.running_var                    (128,)                  torch.cuda.FloatTensor False
# 107   teacher.fc.weight                         (10, 128)               torch.cuda.FloatTensor False
# 108   teacher.fc.bias                           (10,)                   torch.cuda.FloatTensor False
#
# Total number of parameters: 78042
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
#
#
#
#   0%|          | 1/469 [00:00<02:34,  3.03it/s]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.1291e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.2115e-05, device='cuda:0', grad_fn=<MeanBackward0>), tensor(0.0001, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.1291e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.2115e-05, device='cuda:0', grad_fn=<SumBackward0>), tensor(0.0001, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.6392e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.1125e-05, device='cuda:0', grad_fn=<MeanBackward0>), tensor(9.3337e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.6392e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.1125e-05, device='cuda:0', grad_fn=<SumBackward0>), tensor(9.3337e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.4909e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.0150e-05, device='cuda:0', grad_fn=<MeanBackward0>), tensor(6.4360e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.4909e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.0150e-05, device='cuda:0', grad_fn=<SumBackward0>), tensor(6.4360e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.5005e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(8.5135e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.9199e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.5005e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(8.5135e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.9199e-05, device='cuda:0', grad_fn=<SumBackward0>)]
#   1%|          | 4/469 [00:00<01:54,  4.08it/s]
#
#
#   1%|▏         | 7/469 [00:00<01:25,  5.41it/s]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.6436e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(9.3570e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.1323e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.6436e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(9.3570e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.1323e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(7.0138e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(8.7513e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(4.9585e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(7.0138e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(8.7513e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(4.9585e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(7.3306e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(9.7370e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(4.7997e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(7.3306e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(9.7370e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(4.7997e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.7340e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(8.7883e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(4.2651e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.7340e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(8.7883e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(4.2651e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(7.3238e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(8.8565e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(3.9830e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(7.3238e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(8.8565e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(3.9830e-05, device='cuda:0', grad_fn=<SumBackward0>)]
#   2%|▏         | 10/469 [00:00<01:05,  7.03it/s]
#
#
#   3%|▎         | 13/469 [00:00<00:51,  8.92it/s]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(7.3571e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(8.5506e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(3.6087e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(7.3571e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(8.5506e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(3.6087e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.5454e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(8.5125e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(3.7717e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.5454e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(8.5125e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(3.7717e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(7.3292e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(8.5606e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(3.0928e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(7.3292e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(8.5606e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(3.0928e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(7.1437e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(9.8233e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(3.2940e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(7.1437e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(9.8233e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(3.2940e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(7.2636e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(9.9580e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(4.0449e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(7.2636e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(9.9580e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(4.0449e-05, device='cuda:0', grad_fn=<SumBackward0>)]
#   3%|▎         | 16/469 [00:00<00:41, 10.91it/s]
#
#
#   4%|▍         | 19/469 [00:01<00:35, 12.85it/s]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.9841e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(8.6992e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(3.9154e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.9841e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(8.6992e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(3.9154e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(7.5931e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(9.4186e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(3.1232e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(7.5931e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(9.4186e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(3.1232e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(7.7995e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(9.6944e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(3.9189e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(7.7995e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(9.6944e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(3.9189e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(7.1750e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(9.1615e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(3.5282e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(7.1750e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(9.1615e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(3.5282e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.7385e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(9.1465e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(3.0357e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.7385e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(9.1465e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(3.0357e-05, device='cuda:0', grad_fn=<SumBackward0>)]
#   5%|▍         | 22/469 [00:01<00:29, 15.10it/s]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.8383e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(8.4580e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(3.4751e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.8383e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(8.4580e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(3.4751e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.9320e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(8.9290e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(4.1128e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.9320e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(8.9290e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(4.1128e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.0751e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(7.5851e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.9443e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.0751e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(7.5851e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.9443e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.6441e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(8.1964e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(3.1720e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.6441e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(8.1964e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(3.1720e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.9345e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(8.0676e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(3.0348e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.9345e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(8.0676e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(3.0348e-05, device='cuda:0', grad_fn=<SumBackward0>)]
#   5%|▌         | 25/469 [00:01<00:26, 16.87it/s]
#
#
#   6%|▌         | 28/469 [00:01<00:23, 18.91it/s]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.4828e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(7.1991e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.9696e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.4828e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(7.1991e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.9696e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.6915e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(8.1156e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.9302e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.6915e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(8.1156e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.9302e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.6369e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(6.9566e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.9062e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.6369e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(6.9566e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.9062e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.8198e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(7.6590e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.8900e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.8198e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(7.6590e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.8900e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.8292e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(7.2989e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.9682e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.8292e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(7.2989e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.9682e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
#   7%|▋         | 31/469 [00:01<00:21, 19.94it/s]
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(5.7319e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.4032e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.1153e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(5.7319e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.4032e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.1153e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.4796e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.3732e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.4993e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.4796e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.3732e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.4993e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.1196e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(4.7693e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.3550e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.1196e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(4.7693e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.3550e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.1578e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.5447e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.4038e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.1578e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.5447e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.4038e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.0712e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(6.0402e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.9767e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.0712e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(6.0402e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.9767e-05, device='cuda:0', grad_fn=<SumBackward0>)]
#   7%|▋         | 34/469 [00:01<00:21, 20.48it/s]
#
#
#   8%|▊         | 37/469 [00:01<00:20, 21.38it/s]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.1742e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(6.2604e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(3.0896e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.1742e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(6.2604e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(3.0896e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.5616e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(7.3295e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.5094e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.5616e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(7.3295e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.5094e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.1839e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(6.4398e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.7947e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.1839e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(6.4398e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.7947e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.1773e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(6.6297e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.4091e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.1773e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(6.6297e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.4091e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.2068e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(6.1868e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.0130e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.2068e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(6.1868e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.0130e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
#   9%|▊         | 40/469 [00:02<00:19, 22.20it/s]
#
#
#   9%|▉         | 43/469 [00:02<00:18, 23.22it/s]
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(5.8965e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.4496e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.1207e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(5.8965e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.4496e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.1207e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.3556e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.5958e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.3994e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.3556e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.5958e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.3994e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.1059e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(6.6792e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.1312e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.1059e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(6.6792e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.1312e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.0428e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.6666e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.1374e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.0428e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.6666e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.1374e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.0463e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(6.0449e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.8957e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.0463e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(6.0449e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.8957e-05, device='cuda:0', grad_fn=<SumBackward0>)]
#  10%|▉         | 46/469 [00:02<00:18, 22.64it/s]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.3314e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(6.6339e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.4249e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(6.3314e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(6.6339e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(2.4249e-05, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(6.0567e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.6810e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(2.1813e-05, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# ...
#  30%|███       | 142/469 [00:06<00:13, 23.93it/s]
#
#
#  31%|███       | 145/469 [00:06<00:13, 24.63it/s]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(1.8918e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.6108e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(6.1388e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(1.8918e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.6108e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(6.1388e-06, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(1.8552e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.5340e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.3277e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(1.8552e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.5340e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.3277e-06, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(1.9301e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.4624e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.3986e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(1.9301e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.4624e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.3986e-06, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(1.9025e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.2614e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(6.2965e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(1.9025e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.2614e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(6.2965e-06, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(1.8736e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.5147e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(7.3153e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(1.8736e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.5147e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(7.3153e-06, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
#  32%|███▏      | 148/469 [00:06<00:13, 23.78it/s]
# [tensor(1.6422e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.2813e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.2561e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(1.6422e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.2813e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.2561e-06, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(1.5203e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.1031e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.0023e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(1.5203e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.1031e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.0023e-06, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(1.3930e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.4229e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(4.9608e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(1.3930e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.4229e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(4.9608e-06, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(1.4681e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.4438e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(4.7810e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(1.4681e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.4438e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(4.7810e-06, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(1.6195e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.6266e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.3917e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(1.6195e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.6266e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.3917e-06, device='cuda:0', grad_fn=<SumBackward0>)]
#  32%|███▏      | 151/469 [00:06<00:13, 23.43it/s]
#
#
#  33%|███▎      | 154/469 [00:06<00:13, 23.56it/s]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(1.6050e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.8373e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.9982e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(1.6050e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.8373e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.9982e-06, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(1.7142e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.5881e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.4489e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(1.7142e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.5881e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(5.4489e-06, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(1.7661e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.8325e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(6.0592e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(1.7661e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.8325e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(6.0592e-06, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(1.9031e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.8414e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(7.0615e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(1.9031e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.8414e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(7.0615e-06, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(2.0209e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.9688e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(6.7716e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# [tensor(2.0209e-07, device='cuda:0', grad_fn=<SumBackward0>), tensor(1.9688e-06, device='cuda:0', grad_fn=<SumBackward0>), tensor(6.7716e-06, device='cuda:0', grad_fn=<SumBackward0>)]
# INSIDE AT_LOSS
# torch.Size([128, 16, 32, 32])
# torch.Size([128, 32, 32, 32])
# torch.Size([128, 1024])
# torch.Size([128, 1024])
# INSIDE AT_LOSS
# torch.Size([128, 32, 16, 16])
# torch.Size([128, 64, 16, 16])
# torch.Size([128, 256])
# torch.Size([128, 256])
# INSIDE AT_LOSS
# torch.Size([128, 64, 8, 8])
# torch.Size([128, 128, 8, 8])
# torch.Size([128, 64])
# torch.Size([128, 64])
# LOSS _ GROUPS BEFORE
# [tensor(2.1994e-07, device='cuda:0', grad_fn=<MeanBackward0>), tensor(1.9280e-06, device='cuda:0', grad_fn=<MeanBackward0>), tensor(5.9735e-06, device='cuda:0', grad_fn=<MeanBackward0>)]
# 3
# LOSS _ GROUPS AFTER
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-4d17de28b604> in <module>()
#      25
#      26 print('parsed options:', student_trained_args)
# ---> 27 student_trained = model_parameters(student_trained_args)
#      28
#
# <ipython-input-12-9d5c49480e6d> in model_parameters(args)
#     263   engine.hooks['on_end_epoch'] = on_end_epoch
#     264   engine.hooks['on_start'] = on_start
# --> 265   engine.train(h, train_loader, args.epochs, optimizer)
#     266
#     267   return engine
#
# /usr/local/lib/python3.6/dist-packages/torchnet/engine/engine.py in train(self, network, iterator, maxepoch, optimizer)
#      61
#      62                 state['optimizer'].zero_grad()
# ---> 63                 state['optimizer'].step(closure)
#      64                 self.hook('on_update', state)
#      65                 state['t'] += 1
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      13         def decorate_context(*args, **kwargs):
#      14             with self:
# ---> 15                 return func(*args, **kwargs)
#      16         return decorate_context
#      17
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/sgd.py in step(self, closure)
#      84         if closure is not None:
#      85             with torch.enable_grad():
# ---> 86                 loss = closure()
#      87
#      88         for group in self.param_groups:
#
# /usr/local/lib/python3.6/dist-packages/torchnet/engine/engine.py in closure()
#      50
#      51                 def closure():
# ---> 52                     loss, output = state['network'](state['sample'])
#      53                     state['output'] = output
#      54                     state['loss'] = loss
#
# <ipython-input-12-9d5c49480e6d> in h(sample)
#     190             loss_groups = [v.sum() for v in loss_groups]
#     191             print("LOSS _ GROUPS AFTER")
# --> 192             print(loss_groups)
#     193             [m.add(v.item()) for m, v in zip(meters_at, loss_groups)]
#     194             return distillation(y_s, y_t, targets, args.temperature, args.alpha)                    + args.beta * sum(loss_groups), y_s
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in __repr__(self)
#     160         # characters to replace unicode characters with.
#     161         if sys.version_info > (3,):
# --> 162             return torch._tensor_str._str(self)
#     163         else:
#     164             if hasattr(sys.stdout, 'encoding'):
#
# /usr/local/lib/python3.6/dist-packages/torch/_tensor_str.py in _str(self)
#     313                 tensor_str = _tensor_str(self.to_dense(), indent)
#     314             else:
# --> 315                 tensor_str = _tensor_str(self, indent)
#     316
#     317     if self.layout != torch.strided:
#
# /usr/local/lib/python3.6/dist-packages/torch/_tensor_str.py in _tensor_str(self, indent)
#     211     if self.dtype is torch.float16 or self.dtype is torch.bfloat16:
#     212         self = self.float()
# --> 213     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     214     return _tensor_str_with_formatter(self, indent, formatter, summarize)
#     215
#
# /usr/local/lib/python3.6/dist-packages/torch/_tensor_str.py in __init__(self, tensor)
#      98
#      99             for value in nonzero_finite_vals:
# --> 100                 if value != torch.ceil(value):
#     101                     self.int_mode = False
#     102                     break
#
# KeyboardInterrupt:

# %%
student_args = EasyDict({
    "channel": 0,
    "classes": 10,
    "depth": 10,
    "width": 1,
    "dataset" : 'FashionMNIST',
    "dataroot" : '.',
    "dtype" : 'float',
    "nthread" : 4,
    "teacher_id" : '',
    "batch_size" : 128,
    "lr" : 0.1,
    "epochs" : 10,
    "weight_decay" : 0.0005,
    "epoch_step" : '[60, 120, 160]',
    "lr_decay_ratio" : 0.2,
    "resume" : '',
    "randomcrop_pad" : 4,
    "temperature" : 4,
    "alpha" : 0,
    "beta" : 0,
    "gpu_id" : '0',
    "save" : '/content/logs/at_10_1'
})

print('parsed options:', student_args)
student = model_parameters(student_args)
# Out:
#   0%|          | 0/469 [00:00<?, ?it/s]
# parsed options: {'channel': 0, 'classes': 10, 'depth': 10, 'width': 1, 'dataset': 'FashionMNIST', 'dataroot': '.', 'dtype': 'float', 'nthread': 4, 'teacher_id': '', 'batch_size': 128, 'lr': 0.1, 'epochs': 10, 'weight_decay': 0.0005, 'epoch_step': '[60, 120, 160]', 'lr_decay_ratio': 0.2, 'resume': '', 'randomcrop_pad': 4, 'temperature': 4, 'alpha': 0, 'beta': 0, 'gpu_id': '0', 'save': '/content/logs/at_10_1'}
# creating optimizer with lr =  0.1
#
# Parameters:
# 0     conv0                             (16, 1, 3, 3)           torch.cuda.FloatTensor True
# 1     group0.block0.conv0               (16, 16, 3, 3)          torch.cuda.FloatTensor True
# 2     group0.block0.conv1               (16, 16, 3, 3)          torch.cuda.FloatTensor True
# 3     group0.block0.bn0.weight          (16,)                   torch.cuda.FloatTensor True
# 4     group0.block0.bn0.bias            (16,)                   torch.cuda.FloatTensor True
# 5     group0.block0.bn0.running_mean    (16,)                   torch.cuda.FloatTensor False
# 6     group0.block0.bn0.running_var     (16,)                   torch.cuda.FloatTensor False
# 7     group0.block0.bn1.weight          (16,)                   torch.cuda.FloatTensor True
# 8     group0.block0.bn1.bias            (16,)                   torch.cuda.FloatTensor True
# 9     group0.block0.bn1.running_mean    (16,)                   torch.cuda.FloatTensor False
# 10    group0.block0.bn1.running_var     (16,)                   torch.cuda.FloatTensor False
# 11    group1.block0.conv0               (32, 16, 3, 3)          torch.cuda.FloatTensor True
# 12    group1.block0.conv1               (32, 32, 3, 3)          torch.cuda.FloatTensor True
# 13    group1.block0.bn0.weight          (16,)                   torch.cuda.FloatTensor True
# 14    group1.block0.bn0.bias            (16,)                   torch.cuda.FloatTensor True
# 15    group1.block0.bn0.running_mean    (16,)                   torch.cuda.FloatTensor False
# 16    group1.block0.bn0.running_var     (16,)                   torch.cuda.FloatTensor False
# 17    group1.block0.bn1.weight          (32,)                   torch.cuda.FloatTensor True
# 18    group1.block0.bn1.bias            (32,)                   torch.cuda.FloatTensor True
# 19    group1.block0.bn1.running_mean    (32,)                   torch.cuda.FloatTensor False
# 20    group1.block0.bn1.running_var     (32,)                   torch.cuda.FloatTensor False
# 21    group1.block0.convdim             (32, 16, 1, 1)          torch.cuda.FloatTensor True
# 22    group2.block0.conv0               (64, 32, 3, 3)          torch.cuda.FloatTensor True
# 23    group2.block0.conv1               (64, 64, 3, 3)          torch.cuda.FloatTensor True
# 24    group2.block0.bn0.weight          (32,)                   torch.cuda.FloatTensor True
# 25    group2.block0.bn0.bias            (32,)                   torch.cuda.FloatTensor True
# 26    group2.block0.bn0.running_mean    (32,)                   torch.cuda.FloatTensor False
# 27    group2.block0.bn0.running_var     (32,)                   torch.cuda.FloatTensor False
# 28    group2.block0.bn1.weight          (64,)                   torch.cuda.FloatTensor True
# 29    group2.block0.bn1.bias            (64,)                   torch.cuda.FloatTensor True
# 30    group2.block0.bn1.running_mean    (64,)                   torch.cuda.FloatTensor False
# 31    group2.block0.bn1.running_var     (64,)                   torch.cuda.FloatTensor False
# 32    group2.block0.convdim             (64, 32, 1, 1)          torch.cuda.FloatTensor True
# 33    bn.weight                         (64,)                   torch.cuda.FloatTensor True
# 34    bn.bias                           (64,)                   torch.cuda.FloatTensor True
# 35    bn.running_mean                   (64,)                   torch.cuda.FloatTensor False
# 36    bn.running_var                    (64,)                   torch.cuda.FloatTensor False
# 37    fc.weight                         (10, 64)                torch.cuda.FloatTensor True
# 38    fc.bias                           (10,)                   torch.cuda.FloatTensor True
#
# Total number of parameters: 78042
# 100%|██████████| 469/469 [00:13<00:00, 34.65it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# {'channel': 0, 'classes': 10, 'depth': 10, 'width': 1, 'dataset': 'FashionMNIST', 'dataroot': '.', 'dtype': 'float', 'nthread': 4, 'teacher_id': '', 'batch_size': 128, 'lr': 0.1, 'epochs': 10, 'weight_decay': 0.0005, 'epoch_step': '[60, 120, 160]', 'lr_decay_ratio': 0.2, 'resume': '', 'randomcrop_pad': 4, 'temperature': 4, 'alpha': 0, 'beta': 0, 'gpu_id': '0', 'save': '/content/logs/at_10_1', 'train_loss': 0.7520362459011934, 'train_acc': 72.68166666666667, 'test_loss': 1.4189174643045739, 'test_acc': 60.11, 'epoch': 1, 'num_classes': 10, 'n_parameters': 78042, 'train_time': 13.536037921905518, 'test_time': 1.1514101028442383, 'at_losses': [(nan, nan), (nan, nan), (nan, nan)]}
# None
# ==> id: /content/logs/at_10_1 (1/10), test_acc: 60.11
# 100%|██████████| 469/469 [00:13<00:00, 34.62it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# {'channel': 0, 'classes': 10, 'depth': 10, 'width': 1, 'dataset': 'FashionMNIST', 'dataroot': '.', 'dtype': 'float', 'nthread': 4, 'teacher_id': '', 'batch_size': 128, 'lr': 0.1, 'epochs': 10, 'weight_decay': 0.0005, 'epoch_step': '[60, 120, 160]', 'lr_decay_ratio': 0.2, 'resume': '', 'randomcrop_pad': 4, 'temperature': 4, 'alpha': 0, 'beta': 0, 'gpu_id': '0', 'save': '/content/logs/at_10_1', 'train_loss': 0.4356433651975985, 'train_acc': 84.16833333333334, 'test_loss': 1.672426276569125, 'test_acc': 49.660000000000004, 'epoch': 2, 'num_classes': 10, 'n_parameters': 78042, 'train_time': 13.54922342300415, 'test_time': 1.1172783374786377, 'at_losses': [(nan, nan), (nan, nan), (nan, nan)]}
# None
# ==> id: /content/logs/at_10_1 (2/10), test_acc: 49.66
# 100%|██████████| 469/469 [00:13<00:00, 34.74it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# {'channel': 0, 'classes': 10, 'depth': 10, 'width': 1, 'dataset': 'FashionMNIST', 'dataroot': '.', 'dtype': 'float', 'nthread': 4, 'teacher_id': '', 'batch_size': 128, 'lr': 0.1, 'epochs': 10, 'weight_decay': 0.0005, 'epoch_step': '[60, 120, 160]', 'lr_decay_ratio': 0.2, 'resume': '', 'randomcrop_pad': 4, 'temperature': 4, 'alpha': 0, 'beta': 0, 'gpu_id': '0', 'save': '/content/logs/at_10_1', 'train_loss': 0.3798833021731264, 'train_acc': 86.21166666666666, 'test_loss': 1.7928225239620932, 'test_acc': 65.67, 'epoch': 3, 'num_classes': 10, 'n_parameters': 78042, 'train_time': 13.503987550735474, 'test_time': 1.1379954814910889, 'at_losses': [(nan, nan), (nan, nan), (nan, nan)]}
# None
# ==> id: /content/logs/at_10_1 (3/10), test_acc: 65.67
# 100%|██████████| 469/469 [00:13<00:00, 34.67it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# {'channel': 0, 'classes': 10, 'depth': 10, 'width': 1, 'dataset': 'FashionMNIST', 'dataroot': '.', 'dtype': 'float', 'nthread': 4, 'teacher_id': '', 'batch_size': 128, 'lr': 0.1, 'epochs': 10, 'weight_decay': 0.0005, 'epoch_step': '[60, 120, 160]', 'lr_decay_ratio': 0.2, 'resume': '', 'randomcrop_pad': 4, 'temperature': 4, 'alpha': 0, 'beta': 0, 'gpu_id': '0', 'save': '/content/logs/at_10_1', 'train_loss': 0.3513042730118419, 'train_acc': 87.27333333333334, 'test_loss': 0.6467514196528661, 'test_acc': 76.03, 'epoch': 4, 'num_classes': 10, 'n_parameters': 78042, 'train_time': 13.531157732009888, 'test_time': 1.1443262100219727, 'at_losses': [(nan, nan), (nan, nan), (nan, nan)]}
# None
# ==> id: /content/logs/at_10_1 (4/10), test_acc: 76.03
# 100%|██████████| 469/469 [00:13<00:00, 34.30it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# {'channel': 0, 'classes': 10, 'depth': 10, 'width': 1, 'dataset': 'FashionMNIST', 'dataroot': '.', 'dtype': 'float', 'nthread': 4, 'teacher_id': '', 'batch_size': 128, 'lr': 0.1, 'epochs': 10, 'weight_decay': 0.0005, 'epoch_step': '[60, 120, 160]', 'lr_decay_ratio': 0.2, 'resume': '', 'randomcrop_pad': 4, 'temperature': 4, 'alpha': 0, 'beta': 0, 'gpu_id': '0', 'save': '/content/logs/at_10_1', 'train_loss': 0.33300570771892474, 'train_acc': 88.07666666666667, 'test_loss': 0.7118821566617943, 'test_acc': 74.95, 'epoch': 5, 'num_classes': 10, 'n_parameters': 78042, 'train_time': 13.675455331802368, 'test_time': 1.1399693489074707, 'at_losses': [(nan, nan), (nan, nan), (nan, nan)]}
# None
# ==> id: /content/logs/at_10_1 (5/10), test_acc: 74.95
# 100%|██████████| 469/469 [00:13<00:00, 34.77it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# {'channel': 0, 'classes': 10, 'depth': 10, 'width': 1, 'dataset': 'FashionMNIST', 'dataroot': '.', 'dtype': 'float', 'nthread': 4, 'teacher_id': '', 'batch_size': 128, 'lr': 0.1, 'epochs': 10, 'weight_decay': 0.0005, 'epoch_step': '[60, 120, 160]', 'lr_decay_ratio': 0.2, 'resume': '', 'randomcrop_pad': 4, 'temperature': 4, 'alpha': 0, 'beta': 0, 'gpu_id': '0', 'save': '/content/logs/at_10_1', 'train_loss': 0.3229086582086231, 'train_acc': 88.325, 'test_loss': 0.8934873342514039, 'test_acc': 71.8, 'epoch': 6, 'num_classes': 10, 'n_parameters': 78042, 'train_time': 13.48927927017212, 'test_time': 1.1384053230285645, 'at_losses': [(nan, nan), (nan, nan), (nan, nan)]}
# None
# ==> id: /content/logs/at_10_1 (6/10), test_acc: 71.80
# 100%|██████████| 469/469 [00:13<00:00, 34.77it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# {'channel': 0, 'classes': 10, 'depth': 10, 'width': 1, 'dataset': 'FashionMNIST', 'dataroot': '.', 'dtype': 'float', 'nthread': 4, 'teacher_id': '', 'batch_size': 128, 'lr': 0.1, 'epochs': 10, 'weight_decay': 0.0005, 'epoch_step': '[60, 120, 160]', 'lr_decay_ratio': 0.2, 'resume': '', 'randomcrop_pad': 4, 'temperature': 4, 'alpha': 0, 'beta': 0, 'gpu_id': '0', 'save': '/content/logs/at_10_1', 'train_loss': 0.3109663669297944, 'train_acc': 88.64, 'test_loss': 1.0020114651209187, 'test_acc': 68.48, 'epoch': 7, 'num_classes': 10, 'n_parameters': 78042, 'train_time': 13.490202188491821, 'test_time': 1.1207621097564697, 'at_losses': [(nan, nan), (nan, nan), (nan, nan)]}
# None
# ==> id: /content/logs/at_10_1 (7/10), test_acc: 68.48
# 100%|██████████| 469/469 [00:13<00:00, 34.55it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# {'channel': 0, 'classes': 10, 'depth': 10, 'width': 1, 'dataset': 'FashionMNIST', 'dataroot': '.', 'dtype': 'float', 'nthread': 4, 'teacher_id': '', 'batch_size': 128, 'lr': 0.1, 'epochs': 10, 'weight_decay': 0.0005, 'epoch_step': '[60, 120, 160]', 'lr_decay_ratio': 0.2, 'resume': '', 'randomcrop_pad': 4, 'temperature': 4, 'alpha': 0, 'beta': 0, 'gpu_id': '0', 'save': '/content/logs/at_10_1', 'train_loss': 0.304773916472504, 'train_acc': 89.15333333333334, 'test_loss': 1.5166614870481854, 'test_acc': 60.28, 'epoch': 8, 'num_classes': 10, 'n_parameters': 78042, 'train_time': 13.576308965682983, 'test_time': 1.1312522888183594, 'at_losses': [(nan, nan), (nan, nan), (nan, nan)]}
# None
# ==> id: /content/logs/at_10_1 (8/10), test_acc: 60.28
#  19%|█▉        | 88/469 [00:02<00:11, 33.11it/s]
